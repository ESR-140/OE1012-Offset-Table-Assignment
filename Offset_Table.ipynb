# %% [markdown]
# <a href="https://colab.research.google.com/github/ESR-140/OE1012-Offset-Table-Assignment/blob/main/Offset_Table.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ff55881c-95a3-43ad-84a9-60217884ce88" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ff55881c-95a3-43ad-84a9-60217884ce88">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving offset data(2).xlsx to offset data(2) (1).xlsx

# %%
import io
table = pd.read_excel(io.BytesIO(uploaded['offset data(2).xlsx']), sheet_name= 2, usecols= "A:I")
table.head(5)
# Out:
#         X      Y    Y.1    Y.2    Y.3    Y.4    Y.5    Y.6    Y.7
# 0     NaN  Z=3.2  Z=3.4  Z=3.6  Z=3.8    Z=4  Z=4.2  Z=4.4  Z=4.6
# 1   8.150  0.695  0.779  0.881   1.01  1.175  1.382  1.641  1.979
# 2  12.225  1.401  1.574  1.774  2.005  2.275  2.587  2.953  3.398
# 3  16.300  2.271  2.536  2.839  3.183  3.564  3.979  4.426  4.909
# 4  24.450   4.52  4.921  5.339  5.758  6.174  7.285  8.473  9.314

# %%
xcoords = []
ycoords = []
zcoords = []
for colNo in range(table.shape[1]):
  for rowNo in range(table.shape[0]):
    if colNo == 0 or rowNo ==0:
      pass
    else:
      xcoords.append(table.iloc[rowNo, 0])
      ycoords.append(table.iloc[rowNo, colNo])
      zstring = table.iloc[0,colNo]             # To remove z= from z=3.2 and so on
      zstring_sliced = float(zstring[2:])
      zcoords.append(zstring_sliced)

fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')

ax.scatter(xcoords, ycoords, zcoords)
plt.show()

print(zcoords)
# Out:
# [3.2, 3.2, 3.2, 3.2, 3.2, 3.2, 3.2, 3.2, 3.2, 3.2, 3.2, 3.2, 3.2, 3.2, 3.2, 3.2, 3.2, 3.2, 3.2, 3.2, 3.2, 3.2, 3.2, 3.2, 3.2, 3.4, 3.4, 3.4, 3.4, 3.4, 3.4, 3.4, 3.4, 3.4, 3.4, 3.4, 3.4, 3.4, 3.4, 3.4, 3.4, 3.4, 3.4, 3.4, 3.4, 3.4, 3.4, 3.4, 3.4, 3.4, 3.6, 3.6, 3.6, 3.6, 3.6, 3.6, 3.6, 3.6, 3.6, 3.6, 3.6, 3.6, 3.6, 3.6, 3.6, 3.6, 3.6, 3.6, 3.6, 3.6, 3.6, 3.6, 3.6, 3.6, 3.6, 3.8, 3.8, 3.8, 3.8, 3.8, 3.8, 3.8, 3.8, 3.8, 3.8, 3.8, 3.8, 3.8, 3.8, 3.8, 3.8, 3.8, 3.8, 3.8, 3.8, 3.8, 3.8, 3.8, 3.8, 3.8, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.2, 4.2, 4.2, 4.2, 4.2, 4.2, 4.2, 4.2, 4.2, 4.2, 4.2, 4.2, 4.2, 4.2, 4.2, 4.2, 4.2, 4.2, 4.2, 4.2, 4.2, 4.2, 4.2, 4.2, 4.2, 4.4, 4.4, 4.4, 4.4, 4.4, 4.4, 4.4, 4.4, 4.4, 4.4, 4.4, 4.4, 4.4, 4.4, 4.4, 4.4, 4.4, 4.4, 4.4, 4.4, 4.4, 4.4, 4.4, 4.4, 4.4, 4.6, 4.6, 4.6, 4.6, 4.6, 4.6, 4.6, 4.6, 4.6, 4.6, 4.6, 4.6, 4.6, 4.6, 4.6, 4.6, 4.6, 4.6, 4.6, 4.6, 4.6, 4.6, 4.6, 4.6, 4.6]
