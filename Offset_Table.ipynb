# %% [markdown]
# <a href="https://colab.research.google.com/github/ESR-140/OE1012-Offset-Table-Assignment/blob/main/Offset_Table.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d7974a35-0875-47c7-9bdd-528790a77ad1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d7974a35-0875-47c7-9bdd-528790a77ad1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving offset data(2).xlsx to offset data(2) (7).xlsx

# %%
import io
table = pd.read_excel(io.BytesIO(uploaded['offset data(2).xlsx']), sheet_name= 2, usecols= "A:I")
table.tail(5)
table.iloc[25,1]
# Out:
# nan

# %%
xcoords = []
ycoords = []
zcoords = []

for colNo in range(table.shape[1]):
  for rowNo in range(table.shape[0]):
    if colNo == 0 or rowNo ==0 or table.iloc[rowNo, colNo] == np.nan:
      pass
    else:
      xcoords.append(table.iloc[rowNo, 0])
      ycoords.append(table.iloc[rowNo, colNo])
      zstring = table.iloc[0,colNo]             # To remove z= from z=3.2 and so on
      zstring_sliced = float(zstring[2:])
      zcoords.append(zstring_sliced)

fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')

ax.set_xlabel("X axis")
ax.set_ylabel("Y axis")
ax.set_zlabel("Z axis")

ax.set_xlim(0,200)

ax.scatter(xcoords, ycoords, zcoords)
ax.view_init(45,20)

plt.show()
